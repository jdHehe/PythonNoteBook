# %%
## 处理缺失值

import pandas as pd

# %%
melb_data = pd.read_csv('D:\\learningMaterial\\PythonLanguage\\NoteBook\\learning\\Scikit-learn\\melb_data.csv')

# %%
melb_target = melb_data.Price
melb_data.head(3)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN        Yarra  -37.7996    144.9984
# 1          79.0     1900.0        Yarra  -37.8079    144.9934
# 2         150.0     1900.0        Yarra  -37.8093    144.9944
#
#               Regionname Propertycount
# 0  Northern Metropolitan        4019.0
# 1  Northern Metropolitan        4019.0
# ...

# %%
melb_predictor = melb_data.drop(['Price'], axis=1)
melb_predictor
# Out:
#                   Suburb              Address  Rooms Type Method  \
# 0             Abbotsford         85 Turner St      2    h      S
# 1             Abbotsford      25 Bloomburg St      2    h      S
# 2             Abbotsford         5 Charles St      3    h     SP
# 3             Abbotsford     40 Federation La      3    h     PI
# 4             Abbotsford          55a Park St      4    h     VB
# 5             Abbotsford       129 Charles St      2    h      S
# 6             Abbotsford         124 Yarra St      3    h      S
# 7             Abbotsford        98 Charles St      2    h      S
# 8             Abbotsford   6/241 Nicholson St      1    u      S
# 9             Abbotsford        10 Valiant St      2    h      S
# 10            Abbotsford   411/8 Grosvenor St      2    u     VB
# 11            Abbotsford      40 Nicholson St      3    h     VB
# 12            Abbotsford  123/56 Nicholson St      2    u      S
# ...

# %%
cols_with_missing = [col for col in melb_data.columns if melb_data[col].isnull().any()]

# %%
reduced_X_train = melb_data.drop(cols_with_missing, axis=1)
reduced_X_train.head(2)
# Out:
#        Suburb          Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford     85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Landsize  Lattitude  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0     202.0   -37.7996
# 1  4/02/2016       2.5    3067.0       2.0       1.0     156.0   -37.8079
#
#    Longtitude             Regionname  Propertycount
# 0    144.9984  Northern Metropolitan         4019.0
# 1    144.9934  Northern Metropolitan         4019.0

# %%
from sklearn.preprocessing import Imputer
my_imputer = Imputer()
imputed_X_train = my_imputer.fit_transform(melb_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e448d09ed4a4> in <module>()
#       1 from sklearn.preprocessing import Imputer
#       2 my_imputer = Imputer()
# ----> 3 imputed_X_train = my_imputer.fit_transform(melb_data)
#
# D:\software\Anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# D:\software\Anaconda\lib\site-packages\sklearn\preprocessing\imputation.py in fit(self, X, y)
#     153         if self.axis == 0:
#     154             X = check_array(X, accept_sparse='csc', dtype=np.float64,
# ...

# %%
a = melb_data['Car'].isnull()
help(a.item)
# Out:
# Help on method item in module pandas.core.base:
#
# item() method of pandas.core.series.Series instance
#     return the first element of the underlying data as a python
#     scalar

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence
from sklearn.preprocessing import Imputer

# %%
cols_to_use = ['Distance', 'Landsize', 'BuildingArea']
def get_some_data():
    data = pd.read_csv('D:\\learningMaterial\\PythonLanguage\\NoteBook\\learning\\Scikit-learn\\melb_data.csv')
    y = data.Price
    X = data[cols_to_use]
    my_imputer = Imputer()
    imputed_X = my_imputer.fit_transform(X)
    return imputed_X, y
X, y = get_some_data()
my_model = GradientBoostingRegressor()
my_model.fit(X, y)
my_plots, axs = plot_partial_dependence(my_model, 
                                  features=[0,2],
                                  X=X,
                                  feature_names=cols_to_use,
                                  grid_resolution=10)
my_plots

# %%
help(plot_partial_dependence)
# Out:
# Help on function plot_partial_dependence in module sklearn.ensemble.partial_dependence:
#
# plot_partial_dependence(gbrt, X, features, feature_names=None, label=None, n_cols=3, grid_resolution=100, percentiles=(0.05, 0.95), n_jobs=1, verbose=0, ax=None, line_kw=None, contour_kw=None, **fig_kw)
#     Partial dependence plots for ``features``.
#
#     The ``len(features)`` plots are arranged in a grid with ``n_cols``
#     columns. Two-way partial dependence plots are plotted as contour
#     plots.
#
#     Read more in the :ref:`User Guide <partial_dependence>`.
#
#     Parameters
#     ----------
#     gbrt : BaseGradientBoosting
#         A fitted gradient boosting model.
#     X : array-like, shape=(n_samples, n_features)
#         The data on which ``gbrt`` was trained.
#     features : seq of ints, strings, or tuples of ints or strings
#         If seq[i] is an int or a tuple with one int value, a one-way
#         PDP is created; if seq[i] is a tuple of two ints, a two-way
# ...
